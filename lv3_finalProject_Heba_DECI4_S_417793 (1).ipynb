# %% [markdown]
# Task 1 part(1)

# %% [markdown]
# #Step 1: Import the tools we need

# %%
import requests
import pandas as pd

# %% [markdown]
# #Step 2: Define the GitHub API URL to get top 100 machine learning repos

# %%
url = "https://api.github.com/search/repositories?q=machine+learning&sort=stars&order=desc&per_page=100"

# %%
headers = {'User-Agent': 'Mozilla/5.0'}

# %% [markdown]
# #Step 4: Fetch the data from GitHub

# %%
response = requests.get(url, headers=headers)

# %% [markdown]
# #Step 5: Turn the web response into JSON data

# %%
data = response.json()

# %% [markdown]
# #Step 6: Get the list of repositories from the JSON data

# %%
if 'items' in data and len(data['items']) > 0:
    repos_list = data['items']

# %% [markdown]
# #Step 7: Convert the list into a Pandas DataFrame table

# %%
df = pd.DataFrame(repos_list)

# %% [markdown]
# #Step 8: Explore the Data

# %%
df.head()
# Out:
#           id                           node_id                      name  \
# 0   45717250  MDEwOlJlcG9zaXRvcnk0NTcxNzI1MA==                tensorflow
# 1  155220641  MDEwOlJlcG9zaXRvcnkxNTUyMjA2NDE=              transformers
# 2  343965132  MDEwOlJlcG9zaXRvcnkzNDM5NjUxMzI=          ML-For-Beginners
# 3  145553672  MDEwOlJlcG9zaXRvcnkxNDU1NTM2NzI=                    funNLP
# 4   21872392  MDEwOlJlcG9zaXRvcnkyMTg3MjM5Mg==  awesome-machine-learning
#
#                                full_name  private  \
# 0                  tensorflow/tensorflow    False
# 1               huggingface/transformers    False
# 2             microsoft/ML-For-Beginners    False
# 3                  fighting41love/funNLP    False
# 4  josephmisiti/awesome-machine-learning    False
#
#                                                owner  \
# 0  {'login': 'tensorflow', 'id': 15658638, 'node_...
# 1  {'login': 'huggingface', 'id': 25720743, 'node...
# 2  {'login': 'microsoft', 'id': 6154722, 'node_id...
# 3  {'login': 'fighting41love', 'id': 11475294, 'n...
# 4  {'login': 'josephmisiti', 'id': 246302, 'node_...
#
#                                             html_url  \
# 0           https://github.com/tensorflow/tensorflow
# 1        https://github.com/huggingface/transformers
# 2      https://github.com/microsoft/ML-For-Beginners
# 3           https://github.com/fighting41love/funNLP
# 4  https://github.com/josephmisiti/awesome-machin...
#
#                                          description   fork  \
# 0  An Open Source Machine Learning Framework for ...  False
# 1  🤗 Transformers: the model-definition framework...  False
# 2  12 weeks, 26 lessons, 52 quizzes, classic Mach...  False
# 3  中英文敏感词、语言检测、中外手机/电话归属地/运营商查询、名字推断性别、手机号抽取、身份证抽...  False
# 4  A curated list of awesome Machine Learning fra...  False
#
#                                                  url  ...  \
# 0  https://api.github.com/repos/tensorflow/tensor...  ...
# 1  https://api.github.com/repos/huggingface/trans...  ...
# 2  https://api.github.com/repos/microsoft/ML-For-...  ...
# 3  https://api.github.com/repos/fighting41love/fu...  ...
# 4  https://api.github.com/repos/josephmisiti/awes...  ...
#
#   web_commit_signoff_required has_pull_requests pull_request_creation_policy  \
# 0                       False              True                          all
# 1                       False              True                          all
# 2                       False              True                          all
# 3                       False              True                          all
# 4                       False              True                          all
#
#                                               topics visibility  forks  \
# 0  [deep-learning, deep-neural-networks, distribu...     public  76028
# 1  [audio, deep-learning, deepseek, gemma, glm, h...     public  34248
# 2  [data-science, education, machine-learning, ma...     public  21936
# 3                                                 []     public  15267
# 4                                                 []     public  15615
#
#   open_issues watchers default_branch score
# 0        2849   197025         master   1.0
# 1        2379   164106           main   1.0
# 2          11    89380           main   1.0
# 3          53    82453         master   1.0
# 4          25    74031         master   1.0
#
# [5 rows x 82 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 82 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            100 non-null    int64
#  1   node_id                       100 non-null    object
#  2   name                          100 non-null    object
#  3   full_name                     100 non-null    object
#  4   private                       100 non-null    bool
#  5   owner                         100 non-null    object
#  6   html_url                      100 non-null    object
#  7   description                   100 non-null    object
#  8   fork                          100 non-null    bool
#  9   url                           100 non-null    object
#  10  forks_url                     100 non-null    object
#  11  keys_url                      100 non-null    object
#  12  collaborators_url             100 non-null    object
#  13  teams_url                     100 non-null    object
#  14  hooks_url                     100 non-null    object
#  15  issue_events_url              100 non-null    object
#  16  events_url                    100 non-null    object
#  17  assignees_url                 100 non-null    object
#  18  branches_url                  100 non-null    object
#  19  tags_url                      100 non-null    object
#  20  blobs_url                     100 non-null    object
#  21  git_tags_url                  100 non-null    object
#  22  git_refs_url                  100 non-null    object
#  23  trees_url                     100 non-null    object
#  24  statuses_url                  100 non-null    object
#  25  languages_url                 100 non-null    object
#  26  stargazers_url                100 non-null    object
#  27  contributors_url              100 non-null    object
#  28  subscribers_url               100 non-null    object
#  29  subscription_url              100 non-null    object
#  30  commits_url                   100 non-null    object
#  31  git_commits_url               100 non-null    object
#  32  comments_url                  100 non-null    object
#  33  issue_comment_url             100 non-null    object
#  34  contents_url                  100 non-null    object
#  35  compare_url                   100 non-null    object
#  36  merges_url                    100 non-null    object
#  37  archive_url                   100 non-null    object
#  38  downloads_url                 100 non-null    object
#  39  issues_url                    100 non-null    object
#  40  pulls_url                     100 non-null    object
#  41  milestones_url                100 non-null    object
#  42  notifications_url             100 non-null    object
#  43  labels_url                    100 non-null    object
#  44  releases_url                  100 non-null    object
#  45  deployments_url               100 non-null    object
#  46  created_at                    100 non-null    object
#  47  updated_at                    100 non-null    object
#  48  pushed_at                     100 non-null    object
#  49  git_url                       100 non-null    object
#  50  ssh_url                       100 non-null    object
#  51  clone_url                     100 non-null    object
#  52  svn_url                       100 non-null    object
#  53  homepage                      92 non-null     object
#  54  size                          100 non-null    int64
#  55  stargazers_count              100 non-null    int64
#  56  watchers_count                100 non-null    int64
#  57  language                      77 non-null     object
#  58  has_issues                    100 non-null    bool
#  59  has_projects                  100 non-null    bool
#  60  has_downloads                 100 non-null    bool
#  61  has_wiki                      100 non-null    bool
#  62  has_pages                     100 non-null    bool
#  63  has_discussions               100 non-null    bool
#  64  forks_count                   100 non-null    int64
#  65  mirror_url                    0 non-null      object
#  66  archived                      100 non-null    bool
#  67  disabled                      100 non-null    bool
#  68  open_issues_count             100 non-null    int64
#  69  license                       78 non-null     object
#  70  allow_forking                 100 non-null    bool
#  71  is_template                   100 non-null    bool
#  72  web_commit_signoff_required   100 non-null    bool
#  73  has_pull_requests             100 non-null    bool
#  74  pull_request_creation_policy  100 non-null    object
#  75  topics                        100 non-null    object
#  76  visibility                    100 non-null    object
#  77  forks                         100 non-null    int64
#  78  open_issues                   100 non-null    int64
#  79  watchers                      100 non-null    int64
#  80  default_branch                100 non-null    object
#  81  score                         100 non-null    float64
# dtypes: bool(14), float64(1), int64(9), object(58)
# memory usage: 54.6+ KB

# %% [markdown]
# Task 1 part(2)

# %% [markdown]
# # 1. Select required columns

# %%
required_columns = [
    'name', 'owner', 'language', 'stargazers_count',
    'forks_count', 'watchers_count', 'open_issues_count',
    'created_at', 'updated_at', 'license'
]
df = df[required_columns]

# %% [markdown]
# # 2. Extract owner's username from nested dictionary

# %%
def get_owner_name(owner_data):
    if isinstance(owner_data, dict):
        return owner_data['login']
    return owner_data

# %%
df['owner'] = df['owner'].apply(get_owner_name)

# %% [markdown]
# # Step 3: Extract license name using a simple function

# %%
def get_license_name(license_data):
    if isinstance(license_data, dict):
        return license_data['name']
    return 'Unknown'

# %%
df['license'] = df['license'].apply(get_license_name)

# %%
df.head()
# Out:
#                        name           owner          language  \
# 0                tensorflow      tensorflow               C++
# 1              transformers     huggingface            Python
# 2          ML-For-Beginners       microsoft  Jupyter Notebook
# 3                    funNLP  fighting41love            Python
# 4  awesome-machine-learning    josephmisiti            Python
#
#    stargazers_count  forks_count  watchers_count  open_issues_count  \
# 0            197025        76028          197025               2849
# 1            164106        34248          164106               2379
# 2             89380        21936           89380                 11
# 3             82453        15267           82453                 53
# 4             74031        15615           74031                 25
#
#              created_at            updated_at             license
# 0  2015-11-07T01:19:20Z  2026-08-14T20:55:35Z  Apache License 2.0
# 1  2018-10-29T13:56:00Z  2026-08-14T21:04:17Z  Apache License 2.0
# 2  2021-03-03T01:34:05Z  2026-08-14T20:37:14Z         MIT License
# 3  2018-08-21T11:20:39Z  2026-08-14T17:41:28Z             Unknown
# 4  2014-07-15T19:11:19Z  2026-08-14T20:50:23Z               Other

# %% [markdown]
# # Step 4: Handle missing values (fill missing languages with 'Unknown')

# %%
df['language'] = df['language'].fillna('Unknown')

# %% [markdown]
# # Step 5: Remove duplicate records

# %%
df = df.drop_duplicates()

# %% [markdown]
# # Step 6: Convert date columns to proper datetime format

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
df['updated_at'] = pd.to_datetime(df['updated_at'])

# %% [markdown]
# # Step 7: Rename columns for SQL analysis

# %%
df = df.rename(columns={
    'name': 'repo_name',
    'owner': 'owner_username',
    'language': 'primary_language',
    'stargazers_count': 'stars_count',
    'created_at': 'created_date',
    'updated_at': 'updated_date',
    'license': 'license_type'
})

# %%
df.head()
# Out:
#                   repo_name  owner_username  primary_language  stars_count  \
# 0                tensorflow      tensorflow               C++       197025
# 1              transformers     huggingface            Python       164106
# 2          ML-For-Beginners       microsoft  Jupyter Notebook        89380
# 3                    funNLP  fighting41love            Python        82453
# 4  awesome-machine-learning    josephmisiti            Python        74031
#
#    forks_count  watchers_count  open_issues_count              created_date  \
# 0        76028          197025               2849 2015-11-07 01:19:20+00:00
# 1        34248          164106               2379 2018-10-29 13:56:00+00:00
# 2        21936           89380                 11 2021-03-03 01:34:05+00:00
# 3        15267           82453                 53 2018-08-21 11:20:39+00:00
# 4        15615           74031                 25 2014-07-15 19:11:19+00:00
#
#                updated_date        license_type
# 0 2026-08-14 20:55:35+00:00  Apache License 2.0
# 1 2026-08-14 21:04:17+00:00  Apache License 2.0
# 2 2026-08-14 20:37:14+00:00         MIT License
# 3 2026-08-14 17:41:28+00:00             Unknown
# 4 2026-08-14 20:50:23+00:00               Other

# %% [markdown]
# Task 1 part(3)

# %% [markdown]
# # 1. Save the cleaned dataset to a CSV file

# %%
df.to_csv('github_projects.csv', index=False)

# %% [markdown]
# # 2. Reload the CSV file to verify it

# %%
df_verify = pd.read_csv('github_projects.csv')

# %% [markdown]
# # 3. Display the first few rows

# %%
display(df_verify.head())
# Out:
#                   repo_name  owner_username  primary_language  stars_count  \
# 0                tensorflow      tensorflow               C++       197025
# 1              transformers     huggingface            Python       164106
# 2          ML-For-Beginners       microsoft  Jupyter Notebook        89380
# 3                    funNLP  fighting41love            Python        82453
# 4  awesome-machine-learning    josephmisiti            Python        74031
#
#    forks_count  watchers_count  open_issues_count               created_date  \
# 0        76028          197025               2849  2015-11-07 01:19:20+00:00
# 1        34248          164106               2379  2018-10-29 13:56:00+00:00
# 2        21936           89380                 11  2021-03-03 01:34:05+00:00
# 3        15267           82453                 53  2018-08-21 11:20:39+00:00
# 4        15615           74031                 25  2014-07-15 19:11:19+00:00
#
#                 updated_date        license_type
# 0  2026-08-14 20:55:35+00:00  Apache License 2.0
# 1  2026-08-14 21:04:17+00:00  Apache License 2.0
# 2  2026-08-14 20:37:14+00:00         MIT License
# 3  2026-08-14 17:41:28+00:00             Unknown
# 4  2026-08-14 20:50:23+00:00               Other

# %%
df_verify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   repo_name          100 non-null    object
#  1   owner_username     100 non-null    object
#  2   primary_language   100 non-null    object
#  3   stars_count        100 non-null    int64
#  4   forks_count        100 non-null    int64
#  5   watchers_count     100 non-null    int64
#  6   open_issues_count  100 non-null    int64
#  7   created_date       100 non-null    object
#  8   updated_date       100 non-null    object
#  9   license_type       100 non-null    object
# dtypes: int64(4), object(6)
# memory usage: 7.9+ KB

# %% [markdown]
# Task 2 part(1)

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# # 1. Load the cleaned CSV file

# %%
df_sql = pd.read_csv('github_projects.csv')

# %% [markdown]
# # 2. Connect to (or create) the SQLite database file

# %%
conn = sqlite3.connect('github_data.db')

# %% [markdown]
# # 3. Import the dataset into a table named 'Repositories'

# %%
df_sql.to_sql('Repositories', conn, if_exists='replace', index=False)
# Out:
# 100

# %% [markdown]
# # 4 & 5. Verify that the table was created and preview the data

# %%
query = "SELECT * FROM Repositories LIMIT 5"
preview_df = pd.read_sql_query(query, conn)

# %%
display(preview_df)
# Out:
#                   repo_name  owner_username  primary_language  stars_count  \
# 0                tensorflow      tensorflow               C++       197025
# 1              transformers     huggingface            Python       164106
# 2          ML-For-Beginners       microsoft  Jupyter Notebook        89380
# 3                    funNLP  fighting41love            Python        82453
# 4  awesome-machine-learning    josephmisiti            Python        74031
#
#    forks_count  watchers_count  open_issues_count               created_date  \
# 0        76028          197025               2849  2015-11-07 01:19:20+00:00
# 1        34248          164106               2379  2018-10-29 13:56:00+00:00
# 2        21936           89380                 11  2021-03-03 01:34:05+00:00
# 3        15267           82453                 53  2018-08-21 11:20:39+00:00
# 4        15615           74031                 25  2014-07-15 19:11:19+00:00
#
#                 updated_date        license_type
# 0  2026-08-14 20:55:35+00:00  Apache License 2.0
# 1  2026-08-14 21:04:17+00:00  Apache License 2.0
# 2  2026-08-14 20:37:14+00:00         MIT License
# 3  2026-08-14 17:41:28+00:00             Unknown
# 4  2026-08-14 20:50:23+00:00               Other

# %%
conn.close()

# %% [markdown]
# Task 2 part(2)

# %% [markdown]
# # Connect to the SQLite database

# %%
conn = sqlite3.connect('github_data.db')

# %% [markdown]
# # 1. Filter repositories with more than 10,000 stars

# %%
q1 = "SELECT * FROM Repositories WHERE stars_count > 10000"
display(pd.read_sql_query(q1, conn).head())
# Out:
#                   repo_name  owner_username  primary_language  stars_count  \
# 0                tensorflow      tensorflow               C++       197025
# 1              transformers     huggingface            Python       164106
# 2          ML-For-Beginners       microsoft  Jupyter Notebook        89380
# 3                    funNLP  fighting41love            Python        82453
# 4  awesome-machine-learning    josephmisiti            Python        74031
#
#    forks_count  watchers_count  open_issues_count               created_date  \
# 0        76028          197025               2849  2015-11-07 01:19:20+00:00
# 1        34248          164106               2379  2018-10-29 13:56:00+00:00
# 2        21936           89380                 11  2021-03-03 01:34:05+00:00
# 3        15267           82453                 53  2018-08-21 11:20:39+00:00
# 4        15615           74031                 25  2014-07-15 19:11:19+00:00
#
#                 updated_date        license_type
# 0  2026-08-14 20:55:35+00:00  Apache License 2.0
# 1  2026-08-14 21:04:17+00:00  Apache License 2.0
# 2  2026-08-14 20:37:14+00:00         MIT License
# 3  2026-08-14 17:41:28+00:00             Unknown
# 4  2026-08-14 20:50:23+00:00               Other

# %% [markdown]
# # 2. Find repositories whose name contains 'Machine'

# %%
q2 = "SELECT * FROM Repositories WHERE repo_name LIKE '%Machine%'"
display(pd.read_sql_query(q2, conn).head())
# Out:
#                                            repo_name owner_username  \
# 0                           awesome-machine-learning   josephmisiti
# 1  500-AI-Machine-learning-Deep-learning-Computer...  ashishpatel26
# 2            machine-learning-for-software-engineers        ZuzooVn
# 3                          homemade-machine-learning       trekhleb
# 4                awesome-production-machine-learning      EthicalML
#
#    primary_language  stars_count  forks_count  watchers_count  \
# 0            Python        74031        15615           74031
# 1           Unknown        36254         7431           36254
# 2           Unknown        28858         6149           28858
# 3  Jupyter Notebook        24752         4195           24752
# 4           Unknown        20841         2591           20841
#
#    open_issues_count               created_date               updated_date  \
# 0                 25  2014-07-15 19:11:19+00:00  2026-08-14 20:50:23+00:00
# 1                 67  2021-01-02 12:08:37+00:00  2026-08-14 20:59:23+00:00
# 2                 32  2016-10-09 21:20:25+00:00  2026-08-14 15:43:11+00:00
# 3                 31  2018-11-01 04:34:19+00:00  2026-08-14 15:32:32+00:00
# 4                 31  2018-08-15 14:28:41+00:00  2026-08-14 13:12:52+00:00
#
#                                         license_type
# 0                                              Other
# 1                                            Unknown
# 2  Creative Commons Attribution Share Alike 4.0 I...
# 3                                        MIT License
# 4                                        MIT License

# %% [markdown]
# # 3. Display Top 10 repositories based on stars

# %%
q3 = "SELECT * FROM Repositories ORDER BY stars_count DESC LIMIT 10"
display(pd.read_sql_query(q3, conn))
# Out:
#                                            repo_name  owner_username  \
# 0                                         tensorflow      tensorflow
# 1                                       transformers     huggingface
# 2                                   ML-For-Beginners       microsoft
# 3                                             funNLP  fighting41love
# 4                           awesome-machine-learning    josephmisiti
# 5                                       scikit-learn    scikit-learn
# 6                                             gradio      gradio-app
# 7  500-AI-Machine-learning-Deep-learning-Computer...   ashishpatel26
# 8                                        C-Plus-Plus   TheAlgorithms
# 9                                             netron      lutzroeder
#
#    primary_language  stars_count  forks_count  watchers_count  \
# 0               C++       197025        76028          197025
# 1            Python       164106        34248          164106
# 2  Jupyter Notebook        89380        21936           89380
# 3            Python        82453        15267           82453
# 4            Python        74031        15615           74031
# 5            Python        66983        27290           66983
# 6            Python        43364         3572           43364
# 7           Unknown        36254         7431           36254
# 8               C++        34582         7851           34582
# 9        JavaScript        33351         3171           33351
#
#    open_issues_count               created_date               updated_date  \
# 0               2849  2015-11-07 01:19:20+00:00  2026-08-14 20:55:35+00:00
# 1               2379  2018-10-29 13:56:00+00:00  2026-08-14 21:04:17+00:00
# 2                 11  2021-03-03 01:34:05+00:00  2026-08-14 20:37:14+00:00
# 3                 53  2018-08-21 11:20:39+00:00  2026-08-14 17:41:28+00:00
# 4                 25  2014-07-15 19:11:19+00:00  2026-08-14 20:50:23+00:00
# 5               2124  2010-08-17 09:43:38+00:00  2026-08-14 20:50:42+00:00
# 6                182  2018-12-19 08:24:04+00:00  2026-08-14 15:36:05+00:00
# 7                 67  2021-01-02 12:08:37+00:00  2026-08-14 20:59:23+00:00
# 8                 32  2016-07-16 10:19:45+00:00  2026-08-14 16:24:08+00:00
# 9                 18  2010-12-26 12:53:43+00:00  2026-08-14 18:03:42+00:00
#
#                               license_type
# 0                       Apache License 2.0
# 1                       Apache License 2.0
# 2                              MIT License
# 3                                  Unknown
# 4                                    Other
# 5  BSD 3-Clause "New" or "Revised" License
# 6                       Apache License 2.0
# 7                                  Unknown
# 8                              MIT License
# 9                              MIT License

# %% [markdown]
# # 4. Count total number of repositories

# %%
q4 = "SELECT COUNT(*) as total_repositories FROM Repositories"
display(pd.read_sql_query(q4, conn))
# Out:
#    total_repositories
# 0                 100

# %% [markdown]
# # 5. Calculate average number of stars

# %%
q5 = "SELECT AVG(stars_count) as avg_stars FROM Repositories"
display(pd.read_sql_query(q5, conn))
# Out:
#    avg_stars
# 0   20787.75

# %% [markdown]
# # 6. Use logical operators (AND, OR, NOT)

# %%
q6 = """SELECT repo_name, primary_language, stars_count
FROM Repositories
WHERE (primary_language = 'Python' OR primary_language = 'C++')
  AND NOT stars_count < 50000"""
display(pd.read_sql_query(q6, conn))
# Out:
#                   repo_name primary_language  stars_count
# 0                tensorflow              C++       197025
# 1              transformers           Python       164106
# 2                    funNLP           Python        82453
# 3  awesome-machine-learning           Python        74031
# 4              scikit-learn           Python        66983

# %%
df.head()
# Out:
#                   repo_name  owner_username  primary_language  stars_count  \
# 0                tensorflow      tensorflow               C++       197025
# 1              transformers     huggingface            Python       164106
# 2          ML-For-Beginners       microsoft  Jupyter Notebook        89380
# 3                    funNLP  fighting41love            Python        82453
# 4  awesome-machine-learning    josephmisiti            Python        74031
#
#    forks_count  watchers_count  open_issues_count              created_date  \
# 0        76028          197025               2849 2015-11-07 01:19:20+00:00
# 1        34248          164106               2379 2018-10-29 13:56:00+00:00
# 2        21936           89380                 11 2021-03-03 01:34:05+00:00
# 3        15267           82453                 53 2018-08-21 11:20:39+00:00
# 4        15615           74031                 25 2014-07-15 19:11:19+00:00
#
#                updated_date        license_type
# 0 2026-08-14 20:55:35+00:00  Apache License 2.0
# 1 2026-08-14 21:04:17+00:00  Apache License 2.0
# 2 2026-08-14 20:37:14+00:00         MIT License
# 3 2026-08-14 17:41:28+00:00             Unknown
# 4 2026-08-14 20:50:23+00:00               Other

# %% [markdown]
# Task 2 part(3)

# %% [markdown]
# #1. Bar Chart: Top 10 Repositories by Stars

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
top_10 = df.nlargest(10, 'stars_count')

plt.barh(top_10['repo_name'], top_10['stars_count'], color='skyblue')
plt.xlabel('Number of Stars')
plt.ylabel('Repository')
plt.title('Top 10 Machine Learning Repositories by Stars')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# #2. Line Chart: Repository Creation Trend by Year

# %%
df['created_date'] = pd.to_datetime(df['created_date'])
df['created_year'] = df['created_date'].dt.year

yearly_counts = df['created_year'].value_counts().sort_index()

plt.figure(figsize=(9, 4.5))
plt.plot(yearly_counts.index, yearly_counts.values, marker='o', color='teal', linewidth=2)
plt.xlabel('Year Created')
plt.ylabel('Number of Repositories')
plt.title('Repository Creation Trend by Year')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Task 3 part(1)and(2)

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/.git/

# %%
# !git config --global user.email "tohamym821@gmail.com"
# !git config --global user.name "Heba mostafa"

# %%
# !git add .

# %%
# !git commit -m "Initial project commit"
# Out:
# [main 862c5e9] Initial project commit
#  2 files changed, 13 insertions(+), 13 deletions(-)

# %% [markdown]
# # Ethics Reflection

# %% [markdown]
# Question 1: Why is it important to verify data collected from public APIs?
#
# It is important to verify API data to catch missing or broken values, make sure all requested data was fully downloaded without getting cut off by API limits, and prevent incorrect numbers from ruining your final results.
#
# Question 2: Why should data analysts document the source of their data?
#
# Documenting the source builds trust in your work, allows others to re-run your project and get the same results, and ensures you follow copyright laws and API usage rules.
#
# Question 3: How can missing or inaccurate data affect data analysis and decision-making?
#
# Inaccurate or missing data distorts summary statistics like averages and totals, leads to poor or costly decisions based on wrong information, and creates unfair bias in your analysis.
